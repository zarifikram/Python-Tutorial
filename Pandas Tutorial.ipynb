# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon.csv")

# %%
k = df.groupby(["type1"])

# %% [markdown]
# # print distinct type 1 and max hp whose max hp is more than 150

# %%
k = df.groupby("type1").filter(lambda entry : entry["hp"].max() > 150).groupby("type1")["hp"].max()

# %%
k
# Out:
# type1
# dark       223
# dragon     216
# normal     255
# psychic    190
# water      170
# Name: hp, dtype: int64

# %% [markdown]
# #print distinct type1 which has at least 12 type 2 variations

# %%
df.groupby(["type1", "type2"]).first()
# Out:
#                                                     abilities  against_bug  \
# type1 type2
# bug   electric           ['Compoundeyes', 'Unnerve', 'Swarm']          1.0
#       fairy     ['Honey Gather', 'Shield Dust', 'Sweet Veil']          0.5
#       fighting                     ['Swarm', 'Guts', 'Moxie']          0.5
#       fire                            ['Flame Body', 'Swarm']          0.5
#       flying                  ['Compoundeyes', 'Tinted Lens']          0.5
# ...                                                       ...          ...
# water ice              ['Thick Fat', 'Hydration', 'Ice Body']          1.0
#       poison       ['Clear Body', 'Liquid Ooze', 'Rain Dish']          0.5
#       psychic       ['Oblivious', 'Own Tempo', 'Regenerator']          2.0
#       rock          ['Hustle', 'Natural Cure', 'Regenerator']          1.0
#       steel                            ['Torrent', 'Defiant']          0.5
#
# ...

# %%
df.groupby("type1").filter(lambda x : len(x["type2"].unique()) > 13).groupby(["type1", "type2"]).first()
# Out:
#                                                         abilities  \
# type1 type2
# rock  bug                          ['Battle Armor', 'Swift Swim']
#       dark                             ['Sand Stream', 'Unnerve']
#       dragon                             ['Strong Jaw', 'Sturdy']
#       fairy                              ['Clear Body', 'Sturdy']
#       fighting                                      ['Justified']
#       flying                 ['Rock Head', 'Pressure', 'Unnerve']
#       grass                       ['Suction Cups', 'Storm Drain']
#       ground    ['Rock Head', 'Sturdy', 'Sand Veil', 'Magnet P...
#       ice                         ['Refrigerate', 'Snow Warning']
#       poison                                      ['Beast Boost']
#       psychic                                        ['Levitate']
#       steel                              ['Sturdy', 'Soundproof']
#       water           ['Swift Swim', 'Shell Armor', 'Weak Armor']
# ...

# %% [markdown]
# # Print max hp of pokemons grouped by their inital letter if the maxhp is more than 150

# %%
df.groupby(df.name.str[0]).filter(lambda x : x["hp"].max() > 150).groupby(df.name.str[0])["hp"].max()
# Out:
# name
# A    165
# B    255
# C    250
# G    223
# S    160
# W    190
# Z    216
# Name: hp, dtype: int64

# %%
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
df.sort_values("weight_kg", ascending = False, na_position="first", inplace=True)

# %%
df.weight_kg = df.weight_kg * 1000

# %%
df.rename(columns = {"weight_kg" : "weight_grams"})
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
df["percentage_female"] = 100 - df.percentage_male

# %%
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %% [markdown]
# # add two columns
# # take the sum of sp_attack, sp_defence, speed, attack, defence, hp and call it "total_power"
# # based on "total_power", give a ranking of pokemons in "ranking" column
# # e.g the pokemon with highest total_power has the value 1 in "ranking"
# #     the pokemon with lowest total_power has the value 801 in "ranking"

# %%
df["total_power"] = df[["sp_attack", "sp_defense", "speed", "attack", "defense", "hp"]].sum(axis = 1)

# %%
df = df.sort_values("total_power", ascending=False)

# %%
df["ranking"] = [i for i in range(801)]

# %%
df = df.sort_values("pokedex_number")

# %%
df.drop(columns = ["ranking"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6r/ybj42rmx5yzdgsy5vpnr2j980000gn/T/ipykernel_5252/3479189749.py in <module>
# ----> 1 df.drop(columns = ["ranking"], inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
rowThatWillBeDropped = df.iloc[0]

# %%
df = df.drop(index=0, axis = 1)

# %%
df[0] = rowThatWillBeDropped

# %%
df.iloc[801] = rowThatWillBeDropped
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/6r/ybj42rmx5yzdgsy5vpnr2j980000gn/T/ipykernel_5252/3341750893.py in <module>
# ----> 1 df.iloc[801] = rowThatWillBeDropped
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     718             key = com.apply_if_callable(key, self.obj)
#     719         indexer = self._get_setitem_indexer(key)
# --> 720         self._has_valid_setitem_indexer(key)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1459             elif is_integer(i):
#    1460                 if i >= len(ax):
# -> 1461                     raise IndexError("iloc cannot enlarge its target object")
#    1462             elif isinstance(i, dict):
# ...

# %%
df = df.append(rowThatWillBeDropped)

# %%
df = df.sort_values("pokedex_number")

# %%
df = df.drop(columns = [0])

# %%
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
internet1 = pd.read_csv("internet1.csv")
internet2 = pd.read_csv("internet2.csv")
internet3 = pd.read_csv("internet3.csv")

# %%
internet1
# Out:
#          Country  Avg \n(Mbit/s)Ookla
# 0         Canada                75.18
# 1    South Korea               117.95
# 2    Netherlands               108.33
# 3          Japan                44.05
# 4         Norway               134.73
# ..           ...                  ...
# 139        Sudan                 9.50
# 140         Cuba                 9.10
# 141   Tajikistan                 7.05
# 142    Venezuela                 5.68
# 143    Palestine                 4.89
#
# [144 rows x 2 columns]

# %%
internet2
# Out:
#     Country code                            Name  Continental region  \
# 0             IL                          Israel           NEAR EAST
# 1             KG                      Kyrgyzstan   CIS (FORMER USSR)
# 2             FJ                            Fiji             OCEANIA
# 3             IT                           Italy      WESTERN EUROPE
# 4             SD                           Sudan  SUB-SAHARAN AFRICA
# ..           ...                             ...                 ...
# 237           VA         Vatican City (Holy See)              Europe
# 238           VE                       Venezuela       SOUTH AMERICA
# 239           WF               Wallis and Futuna             OCEANIA
# 240           CD  Congo (Democratic Republic of)  SUB-SAHARAN AFRICA
# 241           ZW                        Zimbabwe  SUB-SAHARAN AFRICA
#
#      NO. OF Internet Plans                 Average price of 1GB (USD)  \
# ...

# %%
internet3
# Out:
#                                   Country or area           Subregion  \
# 0                                           China        Eastern Asia
# 1                                           India       Southern Asia
# 2                                   United States    Northern America
# 3                                       Indonesia  South-eastern Asia
# 4                                          Brazil       South America
# ..                                            ...                 ...
# 209  Saint Helena, Ascension and Tristan da Cunha      Western Africa
# 210                              Falkland Islands       South America
# 211                                    Montserrat           Caribbean
# 212                             Wallis and Futuna           Polynesia
# 213                                          Niue           Polynesia
#
#        Region Internet users     Population
# 0        Asia  1,010,740,000  1,427,647,786
# ...

# %% [markdown]
# # find out the subregion with total internet users between 1B to 5B
# # rank the countries with highest percentage of internet users to the population
# # rank the countries according to the difference between the cheapest and most expensive 1GB packs
# # show the max and min internet plans in all continental regions
# # rank the subregions according to their populations
# # show the average most expensive 1GB in all continental regions
# # show the no of internet plans and average price of 1GB(usd) for countries whose name starts with "B" and contains i

# %%
internet3["Internet users"] = internet3["Internet users"].str.replace(",", "")

# %%
internet3["internetUsers"] = [int(internetUsers) for internetUsers in internet3["Internet users"]]

# %%
internet3 = internet3.drop(columns = ["Internet users"])

# %%
internet3.groupby("Subregion").filter(lambda s : (s.internetUsers.sum() > 1000000000 and s.internetUsers.sum() < 5000000000)).groupby("Subregion").sum()
# Out:
#                internetUsers
# Subregion
# Eastern Asia      1207314413
# Southern Asia     1109733568

# %%
import math
internet3 = internet3.drop(index=[98, 197])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6r/ybj42rmx5yzdgsy5vpnr2j980000gn/T/ipykernel_2756/4159452062.py in <module>
#       1 import math
# ----> 2 internet3 = internet3.drop(index=[98, 197])
#       3
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
internet3["Population"] = internet3["Population"].str.replace(",", "")
internet3["population"] = [int(population) for population in internet3["Population"]]
internet3 = internet3.drop(columns = ["Population"])

# %%
internet3["percetageInternetUsersPerPopulation"] = internet3.internetUsers / internet3.population * 100

# %%
internet3 = internet3.sort_values("percetageInternetUsersPerPopulation", ascending=False)

# %%
internet3["ranking"] = [i for i in range(1, 213)]

# %%
internet3 = internet3.sort_index()

# %%
internet3
# Out:
#                                   Country or area           Subregion  \
# 0                                           China        Eastern Asia
# 1                                           India       Southern Asia
# 2                                   United States    Northern America
# 3                                       Indonesia  South-eastern Asia
# 4                                          Brazil       South America
# ..                                            ...                 ...
# 209  Saint Helena, Ascension and Tristan da Cunha      Western Africa
# 210                              Falkland Islands       South America
# 211                                    Montserrat           Caribbean
# 212                             Wallis and Futuna           Polynesia
# 213                                          Niue           Polynesia
#
#        Region  internetUsers  population  percetageInternetUsersPerPopulation  \
# ...
